# %% [markdown]
# # Tests for the Simulated Annealing (SA) optimization algorithm

# %%
from utils import load_dataset, run_sa_algorithm

# %% [markdown]
# ## Small dataset

# %%
jobs = [
    [(0, 3), (1, 2), (2, 2)],
    [(0, 2), (2, 1), (1, 4)],
    [(1, 4), (2, 3)]
]
run_sa_algorithm(
    jobs=jobs, 
    initial_temperature=100,
    cooling_rate=0.85,
    lower_t=0.001
)
# Out:
# 🏆 Best fitness
# (1, 0)(2, 0)(1, 1)(0, 0)(0, 1)(2, 1)(1, 2)(0, 2), Fitness: 11

# %% [markdown]
# ## Medium dataset

# %%
medium_dataset = load_dataset('datasets/mediumDataset.txt')

run_sa_algorithm(
    jobs=medium_dataset, 
    initial_temperature=100,
    cooling_rate=0.85,
    lower_t=0.001
)
# Out:
# 🏆 Best fitness
# (3, 0)(3, 1)(2, 0)(1, 0)(9, 0)(8, 0)(1, 1)(9, 1)(4, 0)(9, 2)(7, 0)(8, 1)(5, 0)(6, 0)(8, 2)(4, 1)(0, 0)(4, 2)(2, 1)(4, 3)(8, 3)(4, 4)(6, 1)(0, 1)(4, 5)(1, 2)(0, 2)(8, 4)(0, 3)(5, 1)(5, 2)(6, 2)(0, 4)(2, 2)(7, 1)(4, 6)(5, 3)(4, 7)(0, 5)(8, 5)(1, 3)(6, 3)(6, 4)(5, 4)(4, 8)(8, 6)(6, 5)(5, 5)(0, 6)(9, 3)(3, 2)(1, 4)(3, 3)(3, 4)(8, 7)(5, 6)(3, 5)(7, 2)(8, 8)(1, 5)(0, 7)(0, 8)(7, 3)(1, 6)(4, 9)(2, 3)(3, 6)(3, 7)(6, 6)(9, 4)(6, 7)(3, 8)(9, 5)(2, 4)(6, 8)(2, 5)(8, 9)(0, 9)(5, 7)(1, 7)(2, 6)(7, 4)(6, 9)(7, 5)(5, 8)(9, 6)(9, 7)(2, 7)(9, 8)(7, 6)(7, 7)(3, 9)(5, 9)(7, 8)(2, 8)(2, 9)(1, 8)(7, 9)(1, 9)(9, 9), Fitness: 1415

# %% [markdown]
# ## Large dataset

# %%
large_dataset = load_dataset('datasets/largeDataset.txt')

run_sa_algorithm(
    jobs=large_dataset, 
    initial_temperature=100,
    cooling_rate=0.85,
    lower_t=0.001
)
# Out:
# 🏆 Best fitness
# (8, 0)(4, 0)(4, 1)(2, 0)(12, 0)(7, 0)(0, 0)(13, 0)(0, 1)(4, 2)(8, 1)(0, 2)(5, 0)(5, 1)(11, 0)(10, 0)(4, 3)(5, 2)(11, 1)(13, 1)(7, 1)(8, 2)(3, 0)(8, 3)(1, 0)(12, 1)(5, 3)(4, 4)(11, 2)(2, 1)(12, 2)(2, 2)(9, 0)(1, 1)(12, 3)(4, 5)(2, 3)(6, 0)(3, 1)(4, 6)(12, 4)(5, 4)(10, 1)(13, 2)(14, 0)(2, 4)(14, 1)(0, 3)(13, 3)(13, 4)(0, 4)(9, 1)(3, 2)(5, 5)(2, 5)(3, 3)(11, 3)(4, 7)(13, 5)(9, 2)(8, 4)(3, 4)(13, 6)(9, 3)(9, 4)(9, 5)(11, 4)(12, 5)(2, 6)(6, 1)(9, 6)(4, 8)(2, 7)(0, 5)(1, 2)(14, 2)(13, 7)(9, 7)(8, 5)(14, 3)(11, 5)(14, 4)(11, 6)(14, 5)(9, 8)(1, 3)(0, 6)(0, 7)(4, 9)(7, 2)(10, 2)(11, 7)(2, 8)(0, 8)(11, 8)(9, 9)(12, 6)(13, 8)(3, 5)(9, 10)(6, 2)(1, 4)(8, 6)(0, 9)(5, 6)(0, 10)(4, 10)(14, 6)(10, 3)(12, 7)(0, 11)(9, 11)(3, 6)(3, 7)(8, 7)(2, 9)(6, 3)(2, 10)(0, 12)(14, 7)(13, 9)(13, 10)(0, 13)(14, 8)(8, 8)(11, 9)(1, 5)(1, 6)(1, 7)(4, 11)(10, 4)(1, 8)(11, 10)(2, 11)(7, 3)(9, 12)(10, 5)(12, 8)(12, 9)(10, 6)(1, 9)(11, 11)(6, 4)(9, 13)(3, 8)(8, 9)(9, 14)(2, 12)(8, 10)(0, 14)(3, 9)(1, 10)(2, 13)(14, 9)(1, 11)(2, 14)(3, 10)(3, 11)(8, 11)(6, 5)(12, 10)(11, 12)(6, 6)(6, 7)(14, 10)(4, 12)(4, 13)(10, 7)(14, 11)(3, 12)(12, 11)(8, 12)(8, 13)(13, 11)(7, 4)(7, 5)(10, 8)(6, 8)(6, 9)(10, 9)(11, 13)(4, 14)(3, 13)(11, 14)(14, 12)(7, 6)(5, 7)(5, 8)(14, 13)(7, 7)(6, 10)(5, 9)(7, 8)(12, 12)(10, 10)(3, 14)(7, 9)(1, 12)(6, 11)(5, 10)(8, 14)(7, 10)(5, 11)(14, 14)(5, 12)(13, 12)(13, 13)(1, 13)(5, 13)(10, 11)(12, 13)(1, 14)(6, 12)(6, 13)(12, 14)(10, 12)(10, 13)(5, 14)(13, 14)(7, 11)(7, 12)(7, 13)(6, 14)(10, 14)(7, 14), Fitness: 2189
