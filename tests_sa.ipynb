# %% [markdown]
# # Tests for the Simulated Annealing (SA) optimization algorithm

# %%
from utils import load_dataset, run_sa_algorithm

# %% [markdown]
# ## Small dataset

# %%
jobs = [
    [(0, 3), (1, 2), (2, 2)],
    [(0, 2), (2, 1), (1, 4)],
    [(1, 4), (2, 3)]
]
run_sa_algorithm(
    jobs=jobs, 
    initial_temperature=100,
    cooling_rate=0.85,
    lower_t=0.001
)
# Out:
# 🏆 Best fitness
# (1, 1)(0, 2)(2, 0)(2, 1)(0, 1)(1, 0)(1, 2)(0, 0), Fitness: 10

# %% [markdown]
# ## Medium dataset

# %%
medium_dataset = load_dataset('mediumDataset.txt')

run_sa_algorithm(
    jobs=medium_dataset, 
    initial_temperature=100,
    cooling_rate=0.85,
    lower_t=0.001
)
# Out:
# 🏆 Best fitness
# (5, 0)(8, 0)(9, 0)(1, 0)(9, 2)(5, 1)(1, 1)(5, 2)(9, 7)(7, 0)(8, 1)(2, 1)(2, 2)(4, 9)(0, 2)(3, 5)(8, 2)(3, 6)(2, 4)(9, 3)(7, 4)(0, 1)(1, 3)(8, 3)(7, 3)(1, 6)(1, 7)(7, 2)(0, 0)(6, 2)(0, 5)(6, 1)(4, 6)(9, 8)(8, 6)(9, 5)(2, 5)(4, 0)(8, 5)(3, 3)(5, 4)(8, 8)(6, 3)(5, 3)(2, 9)(7, 5)(6, 5)(2, 6)(4, 1)(5, 5)(7, 6)(6, 6)(9, 1)(3, 1)(5, 6)(4, 2)(7, 7)(3, 2)(4, 5)(5, 8)(8, 7)(9, 4)(6, 8)(1, 2)(6, 0)(4, 3)(4, 8)(7, 9)(2, 3)(1, 4)(7, 1)(9, 9)(0, 8)(6, 4)(7, 8)(0, 4)(6, 7)(2, 8)(3, 4)(8, 4)(5, 9)(0, 6)(3, 7)(5, 7)(8, 9)(2, 0)(0, 3)(4, 7)(9, 6)(1, 8)(1, 9)(3, 0)(4, 4)(6, 9)(3, 8)(0, 7)(1, 5)(3, 9)(0, 9)(2, 7), Fitness: 1073

# %% [markdown]
# ## Large dataset

# %%
large_dataset = load_dataset('largeDataset.txt')

run_sa_algorithm(
    jobs=large_dataset, 
    initial_temperature=100,
    cooling_rate=0.85,
    lower_t=0.001
)
# Out:
# 🏆 Best fitness
