# %%
from genetic_algorithm import GeneticAlgorithm
from utils import load_dataset
from utils import run_algorithm

# %%
# Small dataset
jobs = [
    [(0, 3), (1, 2), (2, 2)],
    [(0, 2), (2, 1), (1, 4)],
    [(1, 4), (2, 3)]
]

run_algorithm(
    jobs,
    population_size=10,
    selection='rank',
    crossover='two_point',
    mutation='independent',
    visualize=True)
# Out:
# Generation 9: Best Fitness = 12, Avg Fitness = 13.0, Std Dev = 0.49315995495347725
# Generation 10: Best Fitness = 12, Avg Fitness = 12.9375, Std Dev = 0.39786928357164775
# Generation 11: Best Fitness = 12, Avg Fitness = 12.882352941176471, Std Dev = 0.3286480750193431
# Generation 12: Best Fitness = 12, Avg Fitness = 12.833333333333334, Std Dev = 0.2765504930285636
# Generation 13: Best Fitness = 12, Avg Fitness = 12.789473684210526, Std Dev = 0.2362350389022163
# Generation 14: Best Fitness = 12, Avg Fitness = 12.75, Std Dev = 0.2043277866541617
# Generation 15: Best Fitness = 12, Avg Fitness = 12.714285714285714, Std Dev = 0.17860084520400432
# Generation 16: Best Fitness = 12, Avg Fitness = 12.681818181818182, Std Dev = 0.15752909476256405
# Generation 17: Best Fitness = 12, Avg Fitness = 12.652173913043478, Std Dev = 0.14003682081668273
# Generation 18: Best Fitness = 12, Avg Fitness = 12.625, Std Dev = 0.12534589301269267
# Generation 19: Best Fitness = 12, Avg Fitness = 12.6, Std Dev = 0.11288113585427473
# Generation 20: Best Fitness = 12, Avg Fitness = 12.576923076923077, Std Dev = 0.10220934185989453
# Generation 21: Best Fitness = 12, Avg Fitness = 12.555555555555555, Std Dev = 0.09299882021119701
# Generation 22: Best Fitness = 12, Avg Fitness = 12.535714285714286, Std Dev = 0.08499188651349739
# Generation 23: Best Fitness = 12, Avg Fitness = 12.517241379310345, Std Dev = 0.0779857377289767
# Generation 24: Best Fitness = 12, Avg Fitness = 12.5, Std Dev = 0.07181889486349714
# Generation 25: Best Fitness = 12, Avg Fitness = 12.483870967741936, Std Dev = 0.06636142381715275
# Generation 26: Best Fitness = 12, Avg Fitness = 12.46875, Std Dev = 0.06150777029281928
# Generation 27: Best Fitness = 12, Avg Fitness = 12.454545454545455, Std Dev = 0.0571714352179396
# Generation 28: Best Fitness = 12, Avg Fitness = 12.441176470588236, Std Dev = 0.05328096669851617
# Generation 29: Best Fitness = 12, Avg Fitness = 12.428571428571429, Std Dev = 0.04977690734595958
# Generation 30: Best Fitness = 12, Avg Fitness = 12.416666666666666, Std Dev = 0.046609444070458105
# Generation 31: Best Fitness = 12, Avg Fitness = 12.405405405405405, Std Dev = 0.04373658065603118
# Generation 32: Best Fitness = 12, Avg Fitness = 12.394736842105264, Std Dev = 0.04112270374502075
# Generation 33: Best Fitness = 12, Avg Fitness = 12.384615384615385, Std Dev = 0.03873744793506027
# Generation 34: Best Fitness = 12, Avg Fitness = 12.375, Std Dev = 0.0365547904729446
# Generation 35: Best Fitness = 12, Avg Fitness = 12.365853658536585, Std Dev = 0.034552323756147946
# Generation 36: Best Fitness = 12, Avg Fitness = 12.357142857142858, Std Dev = 0.03271066667889169
# Individual 1: Chromosome: [(2, 0), (2, 1), (1, 0), (1, 1), (0, 0), (0, 1), (0, 2), (1, 2)], Fitness: 12
# Individual 2: Chromosome: [(1, 0), (1, 1), (2, 0), (2, 1), (1, 2), (0, 0), (0, 1), (0, 2)], Fitness: 12

# %%
medium_dataset = load_dataset('mediumDataset.txt')

run_algorithm(
    medium_dataset,
    population_size=50,
    selection='rank',
    crossover='two_point',
    mutation='one',
    visualize=True)
# Out:
# (0, 0)(1, 0)(1, 1)(0, 1)(1, 2)(9, 0)(9, 1)(0, 2)(9, 2)(1, 3)(2, 0)(1, 4)(3, 0)(0, 3)(2, 1)(4, 0)(8, 0)(3, 1)(8, 1)(3, 2)(0, 4)(2, 2)(6, 0)(4, 1)(1, 5)(3, 3)(9, 3)(4, 2)(0, 5)(2, 3)(5, 0)(1, 6)(5, 1)(4, 3)(8, 2)(9, 4)(3, 4)(3, 5)(4, 4)(9, 5)(0, 6)(5, 2)(3, 6)(7, 0)(3, 7)(3, 8)(3, 9)(8, 3)(5, 3)(4, 5)(8, 4)(7, 1)(2, 4)(7, 2)(1, 7)(1, 8)(8, 5)(5, 4)(8, 6)(8, 7)(7, 3)(1, 9)(7, 4)(8, 8)(0, 7)(7, 5)(7, 6)(8, 9)(0, 8)(4, 6)(0, 9)(7, 7)(2, 5)(4, 7)(6, 1)(9, 6)(7, 8)(4, 8)(7, 9)(6, 2)(9, 7)(2, 6)(2, 7)(5, 5)(4, 9)(5, 6)(2, 8)(2, 9)(6, 3)(9, 8)(9, 9)(6, 4)(5, 7)(5, 8)(6, 5)(6, 6)(6, 7)(6, 8)(6, 9)(5, 9) (9, 0)(6, 0)(8, 0)(9, 1)(7, 0)(7, 1)(0, 0)(7, 2)(2, 0)(8, 1)(4, 0)(5, 0)(1, 0)(3, 0)(9, 2)(1, 1)(4, 1)(5, 1)(4, 2)(8, 2)(0, 1)(0, 2)(0, 3)(2, 1)(4, 3)(0, 4)(7, 3)(0, 5)(3, 1)(7, 4)(3, 2)(7, 5)(8, 3)(8, 4)(4, 4)(0, 6)(0, 7)(5, 2)(4, 5)(8, 5)(0, 8)(4, 6)(0, 9)(5, 3)(6, 1)(9, 3)(9, 4)(1, 2)(5, 4)(5, 5)(6, 2)(5, 6)(8, 6)(7, 6)(1, 3)(5, 7)(4, 7)(7, 7)(8, 7)(8, 8)(5, 8)(8, 9)(6, 3)(3, 3)(7, 8)(2, 2)(1, 4)(4, 8)(5, 9)(6, 4)(3, 4)(1, 5)(4, 9)(3, 5)(3, 6)(1, 6)(2, 3)(3, 7)(3, 8)(6, 5)(7, 9)(2, 4)(6, 6)(2, 5)(9, 5)(6, 7)(9, 6)(6, 8)(1, 7)(6, 9)(1, 8)(2, 6)(2, 7)(3, 9)(1, 9)(2, 8)(2, 9)(9, 7)(9, 8)(9, 9)
, 3)(8, 1)(6, 4)(5, 5)(7, 3)(8, 2)(5, 6)(7, 4)(6, 5)(5, 7)(3, 3)(2, 3)(7, 5)(0, 8)(7, 6)(2, 4)(8, 3)(6, 6)(4, 6)(2, 5)(4, 7)(5, 8)(1, 5)(6, 7)(2, 6)(1, 6)(9, 4)(7, 7)(5, 9)(4, 8)(4, 9)(0, 9)(3, 4)(2, 7)(7, 8)(6, 8)(1, 7)(8, 4)(6, 9)(1, 8)(2, 8)(1, 9)(2, 9)(3, 5)(8, 5)(9, 5)(7, 9)(9, 6)(3, 6)(8, 6)(8, 7)(8, 8)(8, 9)(3, 7)(9, 7)(9, 8)(9, 9)(3, 8)(3, 9)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 medium_dataset = load_dataset('mediumDataset.txt')
# ----> 3 run_algorithm(
#       4     medium_dataset,
#       5     population_size=50,
#       6     selection='rank',
#       7     crossover='two_point',
#       8     mutation='one',
#       9     visualize=True)
#
# File ~\Desktop\NACHO\UNI\MASTER\NEC\NECActivity2\GeneticAlgorithm\utils.py:52, in run_algorithm(jobs, population_size, selection, crossover, mutation, visualize)
#      35 """
#      36 Run the Genetic Algorithm with given parameters.
#      37
#    (...)
#      43 :param visualize: Boolean flag to plot results.
#      44 """
#      45 ga = GeneticAlgorithm(
#      46     jobs=jobs,
#      47     population_size=population_size,
#    (...)
#      50     mutation_method=mutation
#      51 )
# ---> 52 ga.main_loop()
#      53 best_individuals = ga.elitism()
#      55 print("🏆 Best Individuals")
#
# File ~\Desktop\NACHO\UNI\MASTER\NEC\NECActivity2\GeneticAlgorithm\genetic_algorithm.py:564, in main_loop(self, num_generations, convergence_generations, std_threshold)
#     557 """
#     558 Execute the Genetic Algorithm main loop.
#     559
#     560 :param num_generations: Number of generations to run the algorithm.
#     561 :type num_generations: int
#     562 """
#     563 for generation in range(num_generations):
# --> 564     descendants = []
#     565     for _ in range(int(len(self.population) / 2)):
#     566         # Selection
#     567         ind1, ind2 = self.select_parents()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1187, in _pydevd_bundle.pydevd_cython_win32_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1103, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1065, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:585, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.do_wait_suspend()
#
# File C:\Program Files\JetBrains\PyCharm 2024.2.1\plugins\python-ce\helpers\pydev\pydevd.py:1207, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1204         from_this_thread.append(frame_id)
#    1206 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1207     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2024.2.1\plugins\python-ce\helpers\pydev\pydevd.py:1222, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1219             self._call_mpl_hook()
#    1221         self.process_internal_commands()
# -> 1222         time.sleep(0.01)
#    1224 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1226 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
large_dataset = load_dataset('largeDataset.txt')

run_algorithm(
    large_dataset,
    population_size=10,
    selection='rank',
    crossover='two_point',
    mutation='independent',
    visualize=True)
